# %%
inputs = [
    {"user": "Alice", "amount": 500, "info": "Sale"},
    {"user": "Bob", "amount": 0, "info": "Summary Request"},
    {"user": "Cara", "amount": 1200, "info": "Purchase"},
    {"user": "Dan", "amount": 0, "info": "Customer Report"},
]

# %%
for entry in inputs:
    if entry["amount"] > 0:
        entry["category"] = "TPS"
    else:
        entry["category"] = "MIS"

# %%
import pandas as pd

df = pd.DataFrame(inputs)
print(df)
# Out:
#     user  amount             info category
# 0  Alice     500             Sale      TPS
# 1    Bob       0  Summary Request      MIS
# 2   Cara    1200         Purchase      TPS
# 3    Dan       0  Customer Report      MIS

# %% [markdown]
# # Reflection
#
# This simulation confirms that the system design from Part 1 holds up when implemented. The logic correctly separates transactions (TPS) from summary/report requests (MIS). Seeing this run helps me understand how basic IS concepts apply in real processing.
#
# > Built with learning support from ChatGPT.
# > This notebook is part of my INF1505 mini-project under Echoscope 2025.
